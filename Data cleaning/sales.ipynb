# %%
import pandas as pd

# %%
df = pd.read_csv("Sales_data.csv")

# %%
#df.drop(columns=['unwanted_column1', 'unwanted_column2'], inplace=True)

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_code   500 non-null    object
#  1   product_type   500 non-null    object
#  2   customer_code  500 non-null    object
#  3   custmer_name   500 non-null    object
#  4   customer_type  500 non-null    object
#  5   market_code    500 non-null    object
#  6   markets_name   500 non-null    object
#  7   zone           500 non-null    object
#  8   order_date     500 non-null    object
#  9   cy_date        500 non-null    object
#  10  year           500 non-null    int64
#  11  month_name     500 non-null    object
#  12  date_yy_mmm    500 non-null    object
#  13  sales_qty      500 non-null    int64
#  14  sales_amount   500 non-null    int64
#  15  currency       500 non-null    object
# dtypes: int64(3), object(13)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# product_code     0
# product_type     0
# customer_code    0
# custmer_name     0
# customer_type    0
# market_code      0
# markets_name     0
# zone             0
# order_date       0
# cy_date          0
# year             0
# month_name       0
# date_yy_mmm      0
# sales_qty        0
# sales_amount     0
# currency         0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
customers = df[['customer_code', 'custmer_name', 'customer_type']].drop_duplicates()

# %%
products = df[['product_code', 'product_type']].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20700\829622905.py in <module>
# ----> 1 products = full_df[['product_code', 'product_type']].drop_duplicates()
#
# NameError: name 'full_df' is not defined

# %%
markets = df[['market_code', 'markets_name', 'zone']].drop_duplicates()

markets.rename(columns={'market_code': 'markets_code'}, inplace=True)

# %%
date = df[['order_date', 'cy_date', 'year', 'month_name', 'date_yy_mmm']].drop_duplicates()
# Rename order_date to date (as per your schema)
date.rename(columns={'order_date': 'date'}, inplace=True)

# %%
transactions = df[['product_code', 'customer_code', 'market_code', 'order_date', 'sales_qty', 'sales_amount', 'currency']]
